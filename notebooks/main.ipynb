# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.chdir('..')


# Import utility functions and colors
from src.utils import (
    create_cmap,
    create_multi_cmap,
    show_colors,
    colored_line,
    LANDSCAPE_DIMENSIONS,
    PORTRAIT_DIMENSIONS,
)

# Import all color palettes
from src.utils.colors import (
    taro_colors,
    gvantsa_colors,
    victoria_colors,
    victor_colors,
    victor_colors_2,
    mehdi_colors,
    max_colors,
    max_colors_2,
    jil_colors,
    colormaps,
)

# Import plot functions
from src.plots import (
    warp_plot,
    taylor_expansion_plot,
    tree_plot,
    noisewave_plot,
    step_sine_plot,
    butterfly_plot,
)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for colormap in colormaps:
    show_colors(colormap[1], colormap[0])

# %%
# plot_1(
#     n_lines=1000,
#     index_length=100,
#     phi=0.8,
#     sigma=2000,
#     return_percent_point=50
#     )

# %%
# plot_2(
#     n_lines=200,
#     index_length=5,
#     sigma=50,
#     step=0.001,
#     r_range=[0, 1],
#     g_range=[0, 0],
#     b_range=[1, 0],
#     # plot_vertical = False,
#     # slope=0.05,
#     sigma_error=0,
#     sigma_dispersion = 2,
# )

# %%
# plot_3_test(
#     n_lines=200,
#     index_length=5,
#     sigma=50,
#     step=0.001,
#     r_range=[0, 1],
#     g_range=[0, 0],
#     b_range=[1, 0],
#     # plot_vertical = False,
#     # slope=0.05,
#     sigma_error=0,
#     sigma_dispersion = 2,
#     num_frames=50
# )

# %%
# plot_heart(
#     points = 20
# )

# %%
# noisewave_plot(
#     n_lines=40,
#     dist="uniform",
#     decay_rate=1.8,
#     sigma_initialisation=5,
#     x_length=20,
#     step_size=0.1,
#     one_sided = True,
#     line_thickness = 4,
#     sigma_error=0.05
# )

# %%
# cmap = create_multi_cmap(
#             ["#000000", "#6F6092", "#00587A", "#4F7942"],
#             10
#         )
# print(cmap)

# %%
# step_sine_plot(
#     n_lines=80,
#     dist="normal",
#     x_start = np.pi/2 + 0.75,
#     decay_rate=1,
#     sigma_initialisation=5,
#     x_length=20,
#     step_size=0.1,
#     one_sided = False,
#     line_thickness = 2,
#     block_step_size=2,
#     sigma_error=15,
#     chance_0= 0.1,
#     vertical = True,
#     phi_coef=0.8,
#     midsection_proportion=0.2,
# )

# %%
# # -------------- Create and show plot --------------
# # Some arbitrary function that gives x, y, and color values
# t = np.linspace(-1000, -0.5, 2000)
# x = 0.9 * np.sin(t)
# y = 0.9 * np.cos(1.6 * t)
# color = np.linspace(0, 2, t.size)

# cmap = create_cmap(
#     color_1="#6F6092",
#     color_2="#000000",
#     length=len(t)
# )
# print(cmap)

# # Create a figure and plot the line on it
# fig1, ax1 = plt.subplots()
# lines = colored_line(x, y, color, ax1, linewidth=10, colors=cmap)
# # fig1.colorbar(lines)  # add a color legend

# # Set the axis limits and tick positions
# ax1.set_xlim(-1, 1)
# ax1.set_ylim(-1, 1)
# ax1.set_xticks((-1, 0, 1))
# ax1.set_yticks((-1, 0, 1))
# ax1.set_title("Color at each point")

# plt.show()

# %%
# flower_plot(
#     cycles = 10,
#     step_size = 500,
#     n_cycles = 2,
#     x_start = 1,
#     x_end = 15,
#     )

# %%
# tree_plot(
#     n_lines = 80,
#     x_length = 15,
#     # sigma_dispersion=0,
#     # step_size=0.1,
#     proportions=[0.36, 0, 0.64],
#     # len_base_straight=10,
#     phi_base=1.05,
#     # base_sd=1,
#     branch_segment_length=10,
#     # offset_step=-0.1,
#     branch_angle=np.pi/12,  # new: angle for branching
# )

# %%
taylor_expansion_plot(
    n_terms=30,
    x_start=-25,
    x_end=25,
    bg_color="#E7D7BE",
    line_thickness=20,
    show_actual=True,
    a_b=[-0.5, 10],
    y_lim=[-5, 25],
)

# %%
# butterfly_plot(t_len = int(12*np.pi), step = 0.001, color_len = 30, phi_step =0, line_thickness=2.5)
# # print(victoria_colors.values())

# %%
# warp_plot(
#     num_lines=20,
#     x_start = -8,
#     x_end =8,
#     linewidth = 17.3,
#     )
